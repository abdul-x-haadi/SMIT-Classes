# %% [markdown]
# # Introduction to Myslef
# ---

# %% [markdown]
# ### Personal Information
#
# **Name** : *Abdul Hadi* \
# **Age** : *16 yrs* \
# **Class** : *11th* \
# **School Name** : *Happy Home School* \
# **City** : *Karachi*
#
# ---

# %% [markdown]
# I am a student passionate about technology, entrepreneurship, and building solutions that create real-world impact.
#
# ---

# %% [markdown]
# ### Hobbies
# - Cricket
# - Coding
# - Maths
# - Sleeping
# ---

# %% [markdown]
# ### My Skills
# 1. HTML
# 2. CSS
# 3. Javascript
# 4. Git and Github
# ---

# %% [markdown]
# ### My Goal
#
# To establish a multi-national business.
