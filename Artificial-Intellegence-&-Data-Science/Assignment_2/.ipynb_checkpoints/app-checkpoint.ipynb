# %% [markdown]
# # My Personal Information Using Python Basics
#
# ---

# %%
full_name = "Abdul Hadi"

# %%
age = 16

# %%
height = 68.1

# %%
is_student = True

# %%
favourite_subject = "Maths"

# %%
favourite_number = 14

# %%
percentage = 93.0

# %%
city = "Karachi"

# %%
print("=====My Personal Profile=====")
print("Name : ", full_name)
print("Age : ", age)
print("Height : ", height, "inches")
print("Student : ", is_student)
print("Favourite Subject : ", favourite_subject)
print("Favourite Number : ", favourite_number)
print("Percentage : ", percentage)
print("City : ", city)
# Out:
# =====My Personal Profile=====
# Name :  Abdul Hadi
# Age :  16
# Height :  68.1 inches
# Student :  True
# Favourite Subject :  Maths
# Favourite Number :  14
# Percentage :  93.0
# City :  Karachi
